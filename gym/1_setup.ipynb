# %% [markdown]
# # 1. Install classic control
#
# https://gymnasium.farama.org/environments/classic_control/

# %%
pip install 'gymnasium[classic-control]'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Setup Atari

# %% [markdown]
# https://gymnasium.farama.org/v0.27.1/environments/atari/

# %%
# !pip install "gymnasium[atari]"

# %%
# !pip install "gymnasium[accept-rom-license]"

# %% [markdown]
# # 3. Setup box2D

# %%
# !pip install "gymnasium[box2d]"

# %% [markdown]
# # 4. Validation

# %%
pip install --upgrade --force-reinstall numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import gym
env = gym.make("LunarLander-v2", render_mode="human")
observation, info = env.reset(seed=42)
for _ in range(1000):
   action = env.action_space.sample()  # User-defined policy function
   observation, reward, terminated, truncated, info = env.step(action)

   if terminated or truncated:
      observation, info = env.reset()
env.close()
# Out:
# 2025-02-18 02:53:53.845 python[39599:2514020] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-02-18 02:53:53.845 python[39599:2514020] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# /opt/anaconda3/envs/mygym/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
